# %% [markdown]
# ## Plots dos espectros de mais alta resolução

# %%
# %load_ext autoreload
# %autoreload 2

# %%
## importing libraries
from functions import load_spectrum, plot_spectrum_ax, make_spectrum_panel, plot_overlaid_spectra
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
import astropy.units as u
import pandas as pd

# %%
grading_df = pd.read_csv('Gradings/gradings_info.csv')
grading_df
# Out:
#                root                                               file  \
# 0      jades-gdn-v4     jades-gdn-v4_g395h-f290lp_1181_39353.spec.fits
# 1      jades-gdn-v4     jades-gdn-v4_g395m-f290lp_1181_39353.spec.fits
# 2      jades-gdn-v4     jades-gdn-v4_g140m-f070lp_1181_39353.spec.fits
# 3      jades-gdn-v4     jades-gdn-v4_g235m-f170lp_1181_39353.spec.fits
# 4   jades-gdn198-v4  jades-gdn198-v4_g395h-f290lp_1181_53501.spec.fits
# 5   jades-gdn198-v4  jades-gdn198-v4_g395m-f290lp_1181_53501.spec.fits
# 6      jades-gdn-v4     jades-gdn-v4_g395m-f290lp_1181_53501.spec.fits
# 7      jades-gdn-v4     jades-gdn-v4_g395h-f290lp_1181_53501.spec.fits
# 8   jades-gdn198-v4  jades-gdn198-v4_g235m-f170lp_1181_53501.spec.fits
# 9      jades-gdn-v4     jades-gdn-v4_g235m-f170lp_1181_53501.spec.fits
# 10  jades-gdn198-v4  jades-gdn198-v4_g140m-f070lp_1181_53501.spec.fits
# 11     jades-gdn-v4     jades-gdn-v4_g140m-f070lp_1181_53501.spec.fits
# ...

# %%
jades_68797 = grading_df[grading_df['srcid'] == 68797]
jades_68797
# Out:
#                root                                               file  \
# 12  jades-gdn198-v4  jades-gdn198-v4_g395m-f290lp_1181_68797.spec.fits
# 13     jades-gdn-v4     jades-gdn-v4_g395m-f290lp_1181_68797.spec.fits
# 14  jades-gdn198-v4  jades-gdn198-v4_g395h-f290lp_1181_68797.spec.fits
# 15     jades-gdn-v4     jades-gdn-v4_g395h-f290lp_1181_68797.spec.fits
# 16  jades-gdn198-v4  jades-gdn198-v4_g235m-f170lp_1181_68797.spec.fits
# 17     jades-gdn-v4     jades-gdn-v4_g235m-f170lp_1181_68797.spec.fits
# 18  jades-gdn198-v4  jades-gdn198-v4_g140m-f070lp_1181_68797.spec.fits
# 19     jades-gdn-v4     jades-gdn-v4_g140m-f070lp_1181_68797.spec.fits
#
#             ra       dec  srcid                     msamet  slitid  \
# 12  189.229137  62.14619  68797  jw01181198001_01_msa.fits      34
# 13  189.229137  62.14619  68797  jw01181098001_04_msa.fits     550
# 14  189.229137  62.14619  68797  jw01181198001_01_msa.fits      34
# ...

# %%
spectro_teste = load_spectrum("Gradings/egs-nelsonx-v4_g395m-f290lp_4106_51623.spec.fits", z=6.9843, normalize=False)
# Create a single axis
fig, ax = plt.subplots(figsize=(8, 4))
plot_spectrum_ax(ax, spectro_teste, show_emission_lines=False,
                 xlim=(0.6, 0.7))
plt.show()

# %%
spectro_teste_2 = load_spectrum("Gradings/egs-nelsonx-v4_g395m-f290lp_4106_51623.spec.fits", z=4.9528, normalize=False)
# Create a single axis
fig, ax = plt.subplots(figsize=(8, 4))
plot_spectrum_ax(ax, spectro_teste_2, show_emission_lines=False,
                 xlim=(0.6, 0.7),
                 ylim=(0, 0.2*10**(-17)))
plt.show()

# %%
j68797_zip = list(zip(jades_68797['file'], jades_68797['zfit']))
j68797_zip
# Out:
# [('jades-gdn198-v4_g395m-f290lp_1181_68797.spec.fits', 5.0392),
#  ('jades-gdn-v4_g395m-f290lp_1181_68797.spec.fits', 5.0397),
#  ('jades-gdn198-v4_g395h-f290lp_1181_68797.spec.fits', 5.0404),
#  ('jades-gdn-v4_g395h-f290lp_1181_68797.spec.fits', 5.0397),
#  ('jades-gdn198-v4_g235m-f170lp_1181_68797.spec.fits', 5.04),
#  ('jades-gdn-v4_g235m-f170lp_1181_68797.spec.fits', 5.0397),
#  ('jades-gdn198-v4_g140m-f070lp_1181_68797.spec.fits', 4.9279),
#  ('jades-gdn-v4_g140m-f070lp_1181_68797.spec.fits', 5.0972)]

# %%
spectro_jades_68797 = load_spectrum(f'Gradings/68797/{j68797_zip[0][0]}', z=j68797_zip[0][1])

fig, ax = plt.subplots(figsize=(8, 4))
plot_spectrum_ax(ax, spectro_jades_68797,
                xlim=(0.645, 0.665),
                ylim=(0, 0.9*10**(-17)),
                show_emission_lines=False
                )
plt.show()

# %%
55604
# Out:
# 55604

# %%
## testando abrir o espectro do BlackTHUNDER
## precisa modificar a função read_spectrum_fits para funcionar 
##  flux_col='spec', #"flux",
##  err_col='errs', #"err"


spectro_blackthunder = load_spectrum('Abell2744-QSO1_opt_1D.fits', z=7.03)

fig, ax = plt.subplots(figsize=(8, 4))
plot_spectrum_ax(ax, spectro_blackthunder,
                xlim=(0.65, 0.665),
                ylim=(0, 0.8*10**(-18)),
                show_emission_lines=False
                )
plt.show()

# %% [markdown]
# ## Spectros especiais

# %%
spectro_mombhstar = load_spectrum('DeGraaff_espectros/mom-uds01-v4_prism-clear_5224_150135.spec.fits', z=7.76)

fig, ax = plt.subplots(figsize=(8, 4))
plot_spectrum_ax(ax, spectro_mombhstar,
                xlim=(0.1, 0.7),
                ylim=(0, 0.8*10**(-19)),
                show_emission_lines=False
                )
plt.show()
