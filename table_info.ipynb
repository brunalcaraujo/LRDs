# %% [markdown]
# # Conferir informações da tabela da deGraaff

# %% [markdown]
# "the Balmer decrement is defined as the ratio between the total (i.e. broad+narrow) Hα and Hβ line flux, again assuming that emission from an underlying host galaxy is subdominant."

# %%
# %load_ext autoreload
# %autoreload 2

# %%
## importing libraries
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
import astropy.units as u
import pandas as pd
from astropy.table import Table

# %%
fits.info("deGraaff2025_lrds_withdups_blackbody_eline_fits.fits")
# Out:
# Filename: deGraaff2025_lrds_withdups_blackbody_eline_fits.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  PHOT          1 BinTableHDU     94   134R x 32C   [K, K, 24A, 57A, D, D, D, D, D, K, 196A, L, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D, 5D]

# %%
table = Table.read("deGraaff2025_lrds_withdups_blackbody_eline_fits.fits")

data = {}

for col in table.colnames:
    arr = np.array(table[col])

    if arr.ndim == 1:
        data[col] = arr
    else:
        for i in range(arr.shape[1]):
            data[f"{col}_{i}"] = arr[:, i]

df = pd.DataFrame(data)

df.head()
# Out:
#     pid   srcid                root  \
# 0  6368   43711  b'capers-cos07-v4'
# 1  6368  119334  b'capers-cos10-v4'
# 2  6368   30440  b'capers-cos10-v4'
# 3  6368   32659  b'capers-cos10-v4'
# 4  6368  160387  b'capers-cos13-v4'
#
#                                                 file          ra       dec  \
# 0  b'capers-cos07-v4_prism-clear_6368_43711.spec....  150.102626  2.249597
# 1  b'capers-cos10-v4_prism-clear_6368_119334.spec...  150.136253  2.308030
# 2  b'capers-cos10-v4_prism-clear_6368_30440.spec....  150.120910  2.317934
# 3  b'capers-cos10-v4_prism-clear_6368_32659.spec....  150.124025  2.306827
# 4  b'capers-cos13-v4_prism-clear_6368_160387.spec...  150.129404  2.393668
#
#       zspec  f444w_aper0.1   mu  Ndup  ...    LOI_8446_0    LOI_8446_1  \
# 0  4.420440     181.549630  1.0     0  ...  1.204418e+41  1.329451e+41
# 1  9.294025      55.454540  1.0     0  ...           NaN           NaN
# 2  3.504500     158.032135  1.0     0  ...  1.215027e+41  1.299733e+41
# 3  4.442170      48.655941  1.0     0  ...  5.702253e+39  1.479514e+40
# 4  6.380030      20.098543  1.0     0  ...           NaN           NaN
#
#      LOI_8446_2    LOI_8446_3    LOI_8446_4  logLOI_8446_0  logLOI_8446_1  \
# 0  1.518157e+41  1.713626e+41  1.848623e+41      41.080777      41.123672
# 1           NaN           NaN           NaN            NaN            NaN
# 2  1.428087e+41  1.560501e+41  1.660314e+41      41.084586      41.113854
# 3  3.043077e+40  4.748942e+40  5.941310e+40      39.881385      40.192852
# 4           NaN           NaN           NaN            NaN            NaN
#
#    logLOI_8446_2  logLOI_8446_3  logLOI_8446_4
# 0      41.181317      41.233916      41.266848
# 1            NaN            NaN            NaN
# 2      41.154755      41.193264      41.220190
# 3      40.488408      40.677228      40.774987
# 4            NaN            NaN            NaN
#
# [5 rows x 115 columns]

# %%
print(table.colnames)
# Out:
# ['pid', 'srcid', 'root', 'file', 'ra', 'dec', 'zspec', 'f444w_aper0.1', 'mu', 'Ndup', 'dup_filenames', 'use_dG25', 'lambda_v', 'beta_UV', 'M_UV', 'break_strength', 'beta_MBB', 'Teff', 'peak_wave', 'logL_MBB', 'logL_5100', 'L5100_LMBB', 'Ha_total_ew', 'Hb_total_ew', 'Balmer_dec_total', 'LHa_total', 'logLHa_total', 'OIII_5007_ew', 'LOIII_5007', 'logLOIII_5007', 'LOI_8446', 'logLOI_8446']

# %%
list(df.columns)
# Out:
# ['pid',
#  'srcid',
#  'root',
#  'file',
#  'ra',
#  'dec',
#  'zspec',
#  'f444w_aper0.1',
#  'mu',
#  'Ndup',
#  'dup_filenames_0',
#  'dup_filenames_1',
#  'dup_filenames_2',
#  'dup_filenames_3',
#  'use_dG25',
#  'lambda_v_0',
#  'lambda_v_1',
#  'lambda_v_2',
#  'lambda_v_3',
#  'lambda_v_4',
#  'beta_UV_0',
#  'beta_UV_1',
#  'beta_UV_2',
#  'beta_UV_3',
#  'beta_UV_4',
#  'M_UV_0',
#  'M_UV_1',
#  'M_UV_2',
#  'M_UV_3',
#  'M_UV_4',
#  'break_strength_0',
#  'break_strength_1',
#  'break_strength_2',
#  'break_strength_3',
#  'break_strength_4',
#  'beta_MBB_0',
#  'beta_MBB_1',
#  'beta_MBB_2',
#  'beta_MBB_3',
#  'beta_MBB_4',
#  'Teff_0',
#  'Teff_1',
#  'Teff_2',
#  'Teff_3',
#  'Teff_4',
#  'peak_wave_0',
#  'peak_wave_1',
#  'peak_wave_2',
#  'peak_wave_3',
#  'peak_wave_4',
#  'logL_MBB_0',
#  'logL_MBB_1',
#  'logL_MBB_2',
#  'logL_MBB_3',
#  'logL_MBB_4',
#  'logL_5100_0',
#  'logL_5100_1',
#  'logL_5100_2',
#  'logL_5100_3',
#  'logL_5100_4',
#  'L5100_LMBB_0',
#  'L5100_LMBB_1',
#  'L5100_LMBB_2',
#  'L5100_LMBB_3',
#  'L5100_LMBB_4',
#  'Ha_total_ew_0',
#  'Ha_total_ew_1',
#  'Ha_total_ew_2',
#  'Ha_total_ew_3',
#  'Ha_total_ew_4',
#  'Hb_total_ew_0',
#  'Hb_total_ew_1',
#  'Hb_total_ew_2',
#  'Hb_total_ew_3',
#  'Hb_total_ew_4',
#  'Balmer_dec_total_0',
#  'Balmer_dec_total_1',
#  'Balmer_dec_total_2',
#  'Balmer_dec_total_3',
#  'Balmer_dec_total_4',
#  'LHa_total_0',
#  'LHa_total_1',
#  'LHa_total_2',
#  'LHa_total_3',
#  'LHa_total_4',
#  'logLHa_total_0',
#  'logLHa_total_1',
#  'logLHa_total_2',
#  'logLHa_total_3',
#  'logLHa_total_4',
#  'OIII_5007_ew_0',
#  'OIII_5007_ew_1',
#  'OIII_5007_ew_2',
#  'OIII_5007_ew_3',
#  'OIII_5007_ew_4',
#  'LOIII_5007_0',
#  'LOIII_5007_1',
#  'LOIII_5007_2',
#  'LOIII_5007_3',
#  'LOIII_5007_4',
#  'logLOIII_5007_0',
#  'logLOIII_5007_1',
#  'logLOIII_5007_2',
#  'logLOIII_5007_3',
#  'logLOIII_5007_4',
#  'LOI_8446_0',
#  'LOI_8446_1',
#  'LOI_8446_2',
#  'LOI_8446_3',
#  'LOI_8446_4',
#  'logLOI_8446_0',
#  'logLOI_8446_1',
#  'logLOI_8446_2',
#  'logLOI_8446_3',
#  'logLOI_8446_4']

# %%
## decodificar a coluna file
df["file"] = df["file"].str.decode("utf-8")

## criar uma tabela apenas com colunas de interesse

colunas_de_interesse = ['pid', 'srcid', 'root', 'file', 'ra', 'dec', 'zspec',
                     'Balmer_dec_total_0', 'Balmer_dec_total_1', 'Balmer_dec_total_2','Balmer_dec_total_3','Balmer_dec_total_4',
                     'LHa_total_0','LHa_total_1','LHa_total_2','LHa_total_3','LHa_total_4',   
                     'LOIII_5007_0','LOIII_5007_1','LOIII_5007_2','LOIII_5007_3','LOIII_5007_4',
]

df_subset = df[colunas_de_interesse].copy()
df_subset
# Out:
#       pid   srcid                root  \
# 0    6368   43711  b'capers-cos07-v4'
# 1    6368  119334  b'capers-cos10-v4'
# 2    6368   30440  b'capers-cos10-v4'
# 3    6368   32659  b'capers-cos10-v4'
# 4    6368  160387  b'capers-cos13-v4'
# ..    ...     ...                 ...
# 129  2561   28876       b'uncover-v4'
# 130  2561   38108       b'uncover-v4'
# 131  2561    4286       b'uncover-v4'
# 132  2561   45924       b'uncover-v4'
# 133  2561   49702       b'uncover-v4'
#
#                                                   file          ra        dec  \
# 0     capers-cos07-v4_prism-clear_6368_43711.spec.fits  150.102626   2.249597
# 1    capers-cos10-v4_prism-clear_6368_119334.spec.fits  150.136253   2.308030
# 2     capers-cos10-v4_prism-clear_6368_30440.spec.fits  150.120910   2.317934
# 3     capers-cos10-v4_prism-clear_6368_32659.spec.fits  150.124025   2.306827
# 4    capers-cos13-v4_prism-clear_6368_160387.spec.fits  150.129404   2.393668
# ..                                                 ...         ...        ...
# 129        uncover-v4_prism-clear_2561_28876.spec.fits    3.569597 -30.373223
# 130        uncover-v4_prism-clear_2561_38108.spec.fits    3.530009 -30.358013
# 131         uncover-v4_prism-clear_2561_4286.spec.fits    3.619201 -30.423270
# 132        uncover-v4_prism-clear_2561_45924.spec.fits    3.584760 -30.343628
# 133        uncover-v4_prism-clear_2561_49702.spec.fits    3.547714 -30.333702
#
#         zspec  Balmer_dec_total_0  Balmer_dec_total_1  Balmer_dec_total_2  \
# 0    4.420440            7.660733            7.854381            8.131770
# 1    9.294025                 NaN                 NaN                 NaN
# 2    3.504500            7.001882            7.347297            7.822455
# 3    4.442170            3.211496            3.408269            3.710558
# 4    6.380030            4.507080            5.072039            6.081922
# ..        ...                 ...                 ...                 ...
# 129  7.036244            6.466503            6.709816            7.383194
# 130  4.968462            9.274564            9.682999           10.321250
# 131  5.835225            9.631084            9.892641           10.348170
# 132  4.463361            7.288102            7.483097            7.793566
# 133  4.866683            5.776415            6.290820            7.124892
#
#      Balmer_dec_total_3  Balmer_dec_total_4   LHa_total_0   LHa_total_1  \
# 0              8.423320            8.642884  5.668301e+42  5.704230e+42
# 1                   NaN                 NaN           NaN           NaN
# 2              8.356926            8.722397  2.825816e+42  2.852278e+42
# 3              4.025521            4.282236  7.447690e+41  7.631289e+41
# 4              7.440252            8.931528  2.314057e+42  2.433602e+42
# ..                  ...                 ...           ...           ...
# 129            8.051341            8.612028  2.859931e+42  2.932661e+42
# 130           11.320986           11.932840  5.628233e+42  5.667344e+42
# 131           10.816000           11.123827  9.484496e+42  9.541866e+42
# 132            8.124210            8.349686  1.113253e+44  1.125604e+44
# 133            8.215064            9.018661  1.294679e+42  1.312337e+42
#
#       LHa_total_2   LHa_total_3   LHa_total_4  LOIII_5007_0  LOIII_5007_1  \
# 0    5.758590e+42  5.815786e+42  5.851865e+42  4.000264e+42  4.019672e+42
# 1             NaN           NaN           NaN  2.476371e+41  3.258825e+41
# 2    2.897211e+42  2.936573e+42  2.959784e+42  1.940875e+42  1.963981e+42
# 3    7.921145e+41  8.178681e+41  8.344853e+41  5.652777e+41  5.749388e+41
# 4    2.593018e+42  2.725515e+42  2.840988e+42  1.406226e+42  1.450743e+42
# ..            ...           ...           ...           ...           ...
# 129  3.088474e+42  3.276416e+42  3.447768e+42  8.977127e+40  1.052825e+41
# 130  5.734779e+42  5.796238e+42  5.830719e+42  1.346203e+42  1.364495e+42
# 131  9.637761e+42  9.731975e+42  9.788501e+42  2.497551e+42  2.524050e+42
# 132  1.142370e+44  1.158507e+44  1.167201e+44  1.338523e+43  1.365895e+43
# 133  1.344190e+42  1.376628e+42  1.403176e+42  4.182669e+41  4.304608e+41
#
#      LOIII_5007_2  LOIII_5007_3  LOIII_5007_4
# 0    4.056132e+42  4.091591e+42  4.115029e+42
# 1    4.353137e+41  5.529167e+41  6.301914e+41
# 2    1.990381e+42  2.024247e+42  2.040635e+42
# 3    5.919181e+41  6.089187e+41  6.220264e+41
# 4    1.513514e+42  1.583113e+42  1.627397e+42
# ..            ...           ...           ...
# 129  1.242843e+41  1.451519e+41  1.577188e+41
# 130  1.397564e+42  1.433028e+42  1.453776e+42
# 131  2.566285e+42  2.606307e+42  2.643634e+42
# 132  1.411858e+43  1.452392e+43  1.479734e+43
# 133  4.536770e+41  4.774447e+41  4.915949e+41
#
# [134 rows x 22 columns]

# %%
pd.set_option('display.max_columns', 50)

# calcular Hb utilizando o percentil de 50% do Ha e do Balmer_dec
df_subset['LHb_total_2'] = df_subset['LHa_total_2'] / df_subset['Balmer_dec_total_2']

df_subset.head()
# Out:
#     pid   srcid                root  \
# 0  6368   43711  b'capers-cos07-v4'
# 1  6368  119334  b'capers-cos10-v4'
# 2  6368   30440  b'capers-cos10-v4'
# 3  6368   32659  b'capers-cos10-v4'
# 4  6368  160387  b'capers-cos13-v4'
#
#                                                 file          ra       dec  \
# 0   capers-cos07-v4_prism-clear_6368_43711.spec.fits  150.102626  2.249597
# 1  capers-cos10-v4_prism-clear_6368_119334.spec.fits  150.136253  2.308030
# 2   capers-cos10-v4_prism-clear_6368_30440.spec.fits  150.120910  2.317934
# 3   capers-cos10-v4_prism-clear_6368_32659.spec.fits  150.124025  2.306827
# 4  capers-cos13-v4_prism-clear_6368_160387.spec.fits  150.129404  2.393668
#
#       zspec  Balmer_dec_total_0  Balmer_dec_total_1  Balmer_dec_total_2  \
# 0  4.420440            7.660733            7.854381            8.131770
# 1  9.294025                 NaN                 NaN                 NaN
# 2  3.504500            7.001882            7.347297            7.822455
# 3  4.442170            3.211496            3.408269            3.710558
# 4  6.380030            4.507080            5.072039            6.081922
#
#    Balmer_dec_total_3  Balmer_dec_total_4   LHa_total_0   LHa_total_1  \
# 0            8.423320            8.642884  5.668301e+42  5.704230e+42
# 1                 NaN                 NaN           NaN           NaN
# 2            8.356926            8.722397  2.825816e+42  2.852278e+42
# 3            4.025521            4.282236  7.447690e+41  7.631289e+41
# 4            7.440252            8.931528  2.314057e+42  2.433602e+42
#
#     LHa_total_2   LHa_total_3   LHa_total_4  LOIII_5007_0  LOIII_5007_1  \
# 0  5.758590e+42  5.815786e+42  5.851865e+42  4.000264e+42  4.019672e+42
# 1           NaN           NaN           NaN  2.476371e+41  3.258825e+41
# 2  2.897211e+42  2.936573e+42  2.959784e+42  1.940875e+42  1.963981e+42
# 3  7.921145e+41  8.178681e+41  8.344853e+41  5.652777e+41  5.749388e+41
# 4  2.593018e+42  2.725515e+42  2.840988e+42  1.406226e+42  1.450743e+42
#
#    LOIII_5007_2  LOIII_5007_3  LOIII_5007_4   LHb_total_2
# 0  4.056132e+42  4.091591e+42  4.115029e+42  7.081596e+41
# 1  4.353137e+41  5.529167e+41  6.301914e+41           NaN
# 2  1.990381e+42  2.024247e+42  2.040635e+42  3.703710e+41
# 3  5.919181e+41  6.089187e+41  6.220264e+41  2.134758e+41
# 4  1.513514e+42  1.583113e+42  1.627397e+42  4.263485e+41

# %%
# calcular a razão OIII/Hb utilizando o percentil de 50% do OIII e do Hb
df_subset['LOIII/Hb'] = df_subset['LOIII_5007_2'] / df_subset['LHb_total_2']

df_subset.head()
# Out:
#     pid   srcid                root  \
# 0  6368   43711  b'capers-cos07-v4'
# 1  6368  119334  b'capers-cos10-v4'
# 2  6368   30440  b'capers-cos10-v4'
# 3  6368   32659  b'capers-cos10-v4'
# 4  6368  160387  b'capers-cos13-v4'
#
#                                                 file          ra       dec  \
# 0   capers-cos07-v4_prism-clear_6368_43711.spec.fits  150.102626  2.249597
# 1  capers-cos10-v4_prism-clear_6368_119334.spec.fits  150.136253  2.308030
# 2   capers-cos10-v4_prism-clear_6368_30440.spec.fits  150.120910  2.317934
# 3   capers-cos10-v4_prism-clear_6368_32659.spec.fits  150.124025  2.306827
# 4  capers-cos13-v4_prism-clear_6368_160387.spec.fits  150.129404  2.393668
#
#       zspec  Balmer_dec_total_0  Balmer_dec_total_1  Balmer_dec_total_2  \
# 0  4.420440            7.660733            7.854381            8.131770
# 1  9.294025                 NaN                 NaN                 NaN
# 2  3.504500            7.001882            7.347297            7.822455
# 3  4.442170            3.211496            3.408269            3.710558
# 4  6.380030            4.507080            5.072039            6.081922
#
#    Balmer_dec_total_3  Balmer_dec_total_4   LHa_total_0   LHa_total_1  \
# 0            8.423320            8.642884  5.668301e+42  5.704230e+42
# 1                 NaN                 NaN           NaN           NaN
# 2            8.356926            8.722397  2.825816e+42  2.852278e+42
# 3            4.025521            4.282236  7.447690e+41  7.631289e+41
# 4            7.440252            8.931528  2.314057e+42  2.433602e+42
#
#     LHa_total_2   LHa_total_3   LHa_total_4  LOIII_5007_0  LOIII_5007_1  \
# 0  5.758590e+42  5.815786e+42  5.851865e+42  4.000264e+42  4.019672e+42
# 1           NaN           NaN           NaN  2.476371e+41  3.258825e+41
# 2  2.897211e+42  2.936573e+42  2.959784e+42  1.940875e+42  1.963981e+42
# 3  7.921145e+41  8.178681e+41  8.344853e+41  5.652777e+41  5.749388e+41
# 4  2.593018e+42  2.725515e+42  2.840988e+42  1.406226e+42  1.450743e+42
#
#    LOIII_5007_2  LOIII_5007_3  LOIII_5007_4   LHb_total_2  LOIII/Hb
# 0  4.056132e+42  4.091591e+42  4.115029e+42  7.081596e+41  5.727709
# 1  4.353137e+41  5.529167e+41  6.301914e+41           NaN       NaN
# 2  1.990381e+42  2.024247e+42  2.040635e+42  3.703710e+41  5.374020
# 3  5.919181e+41  6.089187e+41  6.220264e+41  2.134758e+41  2.772764
# 4  1.513514e+42  1.583113e+42  1.627397e+42  4.263485e+41  3.549946

# %%
df_subset["LOIII/Hb"].hist()
df_subset["LOIII/Hb"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 134 entries, 0 to 133
# Series name: LOIII/Hb
# Non-Null Count  Dtype
# --------------  -----
# 128 non-null    float64
# dtypes: float64(1)
# memory usage: 1.2 KB

# %%
plt.hist(df_subset["LOIII/Hb"].dropna(), bins=15)
plt.show()

# %%
df_subset.describe()
# Out:
#                pid         srcid          ra         dec       zspec  \
# count   134.000000  1.340000e+02  134.000000  134.000000  134.000000
# mean   3827.783582  2.385951e+05  126.210570   15.689226    5.184513
# std    1757.759285  6.452716e+05   90.799497   34.933799    1.399179
# min    1180.000000  9.800000e+01    3.530009  -30.423270    2.273488
# 25%    2561.000000  1.533725e+04   34.369806   -5.258381    4.245461
# 50%    4233.000000  4.213900e+04  150.088317    2.306393    5.042192
# 75%    5194.250000  1.531710e+05  214.892249   52.887878    6.042072
# max    6585.000000  4.111584e+06  322.416334   70.198268    9.294025
#
#        Balmer_dec_total_0  Balmer_dec_total_1  Balmer_dec_total_2  \
# count          128.000000          128.000000          128.000000
# mean             7.614128            8.082897            8.988977
# std              2.873911            2.941224            3.177955
# min              2.109849            2.435258            2.896567
# 25%              5.814013            6.344665            7.136126
# 50%              7.564865            7.969536            8.998091
# 75%              9.269232            9.672986           10.421828
# max             15.280783           16.546435           21.384426
#
#        Balmer_dec_total_3  Balmer_dec_total_4   LHa_total_0   LHa_total_1  \
# count          128.000000          128.000000  1.280000e+02  1.280000e+02
# mean            10.265348           11.593748  1.054365e+43  1.064794e+43
# std              3.918938            5.668267  1.711756e+43  1.724203e+43
# min              3.535652            4.074209  2.630752e+41  2.791710e+41
# 25%              7.952227            8.480144  2.600255e+42  2.630538e+42
# 50%             10.063978           10.677753  5.450715e+42  5.537766e+42
# 75%             12.162991           13.463626  8.854132e+42  8.909032e+42
# max             30.125423           40.347046  1.113253e+44  1.125604e+44
#
#         LHa_total_2   LHa_total_3   LHa_total_4  LOIII_5007_0  LOIII_5007_1  \
# count  1.280000e+02  1.280000e+02  1.280000e+02  1.340000e+02  1.340000e+02
# mean   1.080738e+43  1.097180e+43  1.108042e+43  2.200435e+42  2.237803e+42
# std    1.742500e+43  1.760904e+43  1.772498e+43  2.459041e+42  2.480032e+42
# min    3.061542e+41  3.328695e+41  3.511292e+41  2.695332e+40  3.956007e+40
# 25%    2.703734e+42  2.787119e+42  2.831345e+42  4.976573e+41  5.200720e+41
# 50%    5.625672e+42  5.717722e+42  5.761013e+42  1.346851e+42  1.384432e+42
# 75%    9.005354e+42  9.102380e+42  9.170123e+42  3.058207e+42  3.117549e+42
# max    1.142370e+44  1.158507e+44  1.167201e+44  1.338523e+43  1.365895e+43
#
#        LOIII_5007_2  LOIII_5007_3  LOIII_5007_4   LHb_total_2    LOIII/Hb
# count  1.340000e+02  1.340000e+02  1.340000e+02  1.280000e+02  128.000000
# mean   2.298007e+42  2.359518e+42  2.400179e+42  1.146583e+42    2.682009
# std    2.514012e+42  2.548055e+42  2.570753e+42  1.931772e+42    1.562876
# min    5.899188e+40  8.086549e+40  9.489867e+40  6.899611e+40    0.091760
# 25%    5.581549e+41  5.916128e+41  6.235783e+41  3.478616e+41    1.457090
# 50%    1.458786e+42  1.548176e+42  1.608773e+42  5.883422e+41    2.541149
# 75%    3.205245e+42  3.281960e+42  3.351992e+42  9.475229e+41    3.715631
# max    1.411858e+43  1.452392e+43  1.479734e+43  1.465787e+43    6.506466

# %% [markdown]
# ## Utilizando os dados do Pedro

# %%
tabela_pedro = pd.read_csv('tabela_filtrada.csv')
tabela_pedro.head()
# Out:
#    Unnamed: 0                                               file         z  \
# 0           0  /content/LRDs/DeGraaff_espectros/capers-cos07-...  4.420440
# 1           1  /content/LRDs/DeGraaff_espectros/capers-cos10-...  9.294025
# 2           2  /content/LRDs/DeGraaff_espectros/capers-cos10-...  3.504500
# 3           3  /content/LRDs/DeGraaff_espectros/capers-cos10-...  4.442170
# 4           4  /content/LRDs/DeGraaff_espectros/capers-cos19-...  3.724103
#
#    normalized   norm_factor  norm_error  median_flux_1500A  window_at_1500A  \
# 0        True  2.696274e-20         NaN           3.312191            300.0
# 1        True  5.292462e-21         NaN           2.785926            300.0
# 2        True  2.036766e-20         NaN           3.653128            300.0
# 3        True  5.627498e-21         NaN           5.166089            300.0
# 4        True  6.923923e-20         NaN           3.244394            300.0
#
#    points_within_window1500A  median_flux_1900A  window_at_1900A  \
# 0                       19.0           2.600150            300.0
# 1                       16.0           2.629840            300.0
# 2                       25.0           2.397696            300.0
# 3                       19.0           4.510372            300.0
# 4                       23.0           2.246134            300.0
#
#    points_within_window1900A  median_flux_5500A  window_at_5500A  \
# 0                       12.0           1.310892            200.0
# 1                       17.0                NaN            200.0
# 2                       14.0           0.638679            200.0
# 3                       11.0           1.331673            200.0
# 4                       13.0           0.862579            200.0
#
#    points_within_window5500A
# 0                        8.0
# 1                        0.0
# 2                        6.0
# 3                        8.0
# 4                        6.0

# %%
## preparando para o merge
tabela_pedro["file"] = tabela_pedro["file"].str.split("/").str[-1]
tabela_pedro.drop(columns=["Unnamed: 0"], inplace=True)
tabela_pedro.head()
# Out:
#                                                 file         z  normalized  \
# 0   capers-cos07-v4_prism-clear_6368_43711.spec.fits  4.420440        True
# 1  capers-cos10-v4_prism-clear_6368_119334.spec.fits  9.294025        True
# 2   capers-cos10-v4_prism-clear_6368_30440.spec.fits  3.504500        True
# 3   capers-cos10-v4_prism-clear_6368_32659.spec.fits  4.442170        True
# 4    capers-cos19-v4_prism-clear_6368_9226.spec.fits  3.724103        True
#
#     norm_factor  norm_error  median_flux_1500A  window_at_1500A  \
# 0  2.696274e-20         NaN           3.312191            300.0
# 1  5.292462e-21         NaN           2.785926            300.0
# 2  2.036766e-20         NaN           3.653128            300.0
# 3  5.627498e-21         NaN           5.166089            300.0
# 4  6.923923e-20         NaN           3.244394            300.0
#
#    points_within_window1500A  median_flux_1900A  window_at_1900A  \
# 0                       19.0           2.600150            300.0
# 1                       16.0           2.629840            300.0
# 2                       25.0           2.397696            300.0
# 3                       19.0           4.510372            300.0
# 4                       23.0           2.246134            300.0
#
#    points_within_window1900A  median_flux_5500A  window_at_5500A  \
# 0                       12.0           1.310892            200.0
# 1                       17.0                NaN            200.0
# 2                       14.0           0.638679            200.0
# 3                       11.0           1.331673            200.0
# 4                       13.0           0.862579            200.0
#
#    points_within_window5500A
# 0                        8.0
# 1                        0.0
# 2                        6.0
# 3                        8.0
# 4                        6.0

# %%
## Merge

df_merged = df_subset.merge(tabela_pedro, on="file")
df_merged
# Out:
#      pid   srcid                root  \
# 0   6368   43711  b'capers-cos07-v4'
# 1   6368  119334  b'capers-cos10-v4'
# 2   6368   30440  b'capers-cos10-v4'
# 3   6368   32659  b'capers-cos10-v4'
# 4   6368    9226  b'capers-cos19-v4'
# ..   ...     ...                 ...
# 95  2561   20466       b'uncover-v4'
# 96  2561   28876       b'uncover-v4'
# 97  2561   38108       b'uncover-v4'
# 98  2561    4286       b'uncover-v4'
# 99  2561   45924       b'uncover-v4'
#
#                                                  file          ra        dec  \
# 0    capers-cos07-v4_prism-clear_6368_43711.spec.fits  150.102626   2.249597
# 1   capers-cos10-v4_prism-clear_6368_119334.spec.fits  150.136253   2.308030
# 2    capers-cos10-v4_prism-clear_6368_30440.spec.fits  150.120910   2.317934
# 3    capers-cos10-v4_prism-clear_6368_32659.spec.fits  150.124025   2.306827
# 4     capers-cos19-v4_prism-clear_6368_9226.spec.fits  150.175938   2.432430
# ..                                                ...         ...        ...
# 95        uncover-v4_prism-clear_2561_20466.spec.fits    3.640408 -30.386438
# 96        uncover-v4_prism-clear_2561_28876.spec.fits    3.569597 -30.373223
# 97        uncover-v4_prism-clear_2561_38108.spec.fits    3.530009 -30.358013
# 98         uncover-v4_prism-clear_2561_4286.spec.fits    3.619201 -30.423270
# 99        uncover-v4_prism-clear_2561_45924.spec.fits    3.584760 -30.343628
#
#        zspec  Balmer_dec_total_0  Balmer_dec_total_1  Balmer_dec_total_2  \
# 0   4.420440            7.660733            7.854381            8.131770
# 1   9.294025                 NaN                 NaN                 NaN
# 2   3.504500            7.001882            7.347297            7.822455
# 3   4.442170            3.211496            3.408269            3.710558
# 4   3.724103           10.322535           10.786400           11.570909
# ..       ...                 ...                 ...                 ...
# 95  8.509481                 NaN                 NaN                 NaN
# 96  7.036244            6.466503            6.709816            7.383194
# 97  4.968462            9.274564            9.682999           10.321250
# 98  5.835225            9.631084            9.892641           10.348170
# 99  4.463361            7.288102            7.483097            7.793566
#
#     Balmer_dec_total_3  Balmer_dec_total_4   LHa_total_0   LHa_total_1  \
# 0             8.423320            8.642884  5.668301e+42  5.704230e+42
# 1                  NaN                 NaN           NaN           NaN
# 2             8.356926            8.722397  2.825816e+42  2.852278e+42
# 3             4.025521            4.282236  7.447690e+41  7.631289e+41
# 4            12.370488           13.004778  1.198086e+43  1.209660e+43
# ..                 ...                 ...           ...           ...
# 95                 NaN                 NaN           NaN           NaN
# 96            8.051341            8.612028  2.859931e+42  2.932661e+42
# 97           11.320986           11.932840  5.628233e+42  5.667344e+42
# 98           10.816000           11.123827  9.484496e+42  9.541866e+42
# 99            8.124210            8.349686  1.113253e+44  1.125604e+44
#
#      LHa_total_2   LHa_total_3   LHa_total_4  LOIII_5007_0  LOIII_5007_1  \
# 0   5.758590e+42  5.815786e+42  5.851865e+42  4.000264e+42  4.019672e+42
# 1            NaN           NaN           NaN  2.476371e+41  3.258825e+41
# 2   2.897211e+42  2.936573e+42  2.959784e+42  1.940875e+42  1.963981e+42
# 3   7.921145e+41  8.178681e+41  8.344853e+41  5.652777e+41  5.749388e+41
# 4   1.228081e+43  1.247075e+43  1.259925e+43  6.222170e+42  6.279176e+42
# ..           ...           ...           ...           ...           ...
# 95           NaN           NaN           NaN  3.347765e+42  3.423863e+42
# 96  3.088474e+42  3.276416e+42  3.447768e+42  8.977127e+40  1.052825e+41
# 97  5.734779e+42  5.796238e+42  5.830719e+42  1.346203e+42  1.364495e+42
# 98  9.637761e+42  9.731975e+42  9.788501e+42  2.497551e+42  2.524050e+42
# 99  1.142370e+44  1.158507e+44  1.167201e+44  1.338523e+43  1.365895e+43
#
#     LOIII_5007_2  LOIII_5007_3  LOIII_5007_4   LHb_total_2  LOIII/Hb  \
# 0   4.056132e+42  4.091591e+42  4.115029e+42  7.081596e+41  5.727709
# 1   4.353137e+41  5.529167e+41  6.301914e+41           NaN       NaN
# 2   1.990381e+42  2.024247e+42  2.040635e+42  3.703710e+41  5.374020
# 3   5.919181e+41  6.089187e+41  6.220264e+41  2.134758e+41  2.772764
# 4   6.369545e+42  6.459206e+42  6.515543e+42  1.061352e+42  6.001349
# ..           ...           ...           ...           ...       ...
# 95  3.517831e+42  3.612039e+42  3.691941e+42           NaN       NaN
# 96  1.242843e+41  1.451519e+41  1.577188e+41  4.183113e+41  0.297110
# 97  1.397564e+42  1.433028e+42  1.453776e+42  5.556283e+41  2.515285
# 98  2.566285e+42  2.606307e+42  2.643634e+42  9.313493e+41  2.755449
# 99  1.411858e+43  1.452392e+43  1.479734e+43  1.465787e+43  0.963208
#
#            z  normalized   norm_factor  norm_error  median_flux_1500A  \
# 0   4.420440        True  2.696274e-20         NaN           3.312191
# 1   9.294025        True  5.292462e-21         NaN           2.785926
# 2   3.504500        True  2.036766e-20         NaN           3.653128
# 3   4.442170        True  5.627498e-21         NaN           5.166089
# 4   3.724103        True  6.923923e-20         NaN           3.244394
# ..       ...         ...           ...         ...                ...
# 95  8.509481        True  9.893854e-21         NaN           1.527794
# 96  7.036244        True  4.466745e-21         NaN           4.077500
# 97  4.968462        True  1.365197e-20         NaN           6.000150
# 98  5.835225        True  1.477175e-20         NaN           4.065971
# 99  4.463361        True  1.357041e-19         NaN           1.636384
#
#     window_at_1500A  points_within_window1500A  median_flux_1900A  \
# 0             300.0                       19.0           2.600150
# 1             300.0                       16.0           2.629840
# 2             300.0                       25.0           2.397696
# 3             300.0                       19.0           4.510372
# 4             300.0                       23.0           2.246134
# ..              ...                        ...                ...
# 95            300.0                       15.0           1.356081
# 96            300.0                       14.0           4.109363
# 97            300.0                       17.0           4.101864
# 98            300.0                       15.0           2.328712
# 99            300.0                       18.0           1.931492
#
#     window_at_1900A  points_within_window1900A  median_flux_5500A  \
# 0             300.0                       12.0           1.310892
# 1             300.0                       17.0                NaN
# 2             300.0                       14.0           0.638679
# 3             300.0                       11.0           1.331673
# 4             300.0                       13.0           0.862579
# ..              ...                        ...                ...
# 95            300.0                       15.0           1.178660
# 96            300.0                       12.0           1.972952
# 97            300.0                       12.0           1.363045
# 98            300.0                       11.0           2.097304
# 99            300.0                       11.0           3.468359
#
#     window_at_5500A  points_within_window5500A
# 0             200.0                        8.0
# 1             200.0                        0.0
# 2             200.0                        6.0
# 3             200.0                        8.0
# 4             200.0                        6.0
# ..              ...                        ...
# 95            200.0                       26.0
# 96            200.0                       18.0
# 97            200.0                       10.0
# 98            200.0                       13.0
# 99            200.0                        9.0
#
# [100 rows x 37 columns]

# %%
df_merged[["zspec", "z"]]
np.allclose(df_merged["zspec"], df_merged["z"], equal_nan=True)
# Out:
# True

# %%
plt.hist(df_merged["LOIII/Hb"].dropna(), bins=10)
plt.show()

# %%
plt.scatter(
    df_merged['LOIII/Hb'],
    df_merged['median_flux_5500A']
)

plt.xlabel('LOIII/Hb')
plt.ylabel("5500 flux")
plt.show()
